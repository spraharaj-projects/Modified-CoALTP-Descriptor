# %%
import numpy as np
import glob
import math
from skimage import io,color,feature,exposure
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline

# %%
def SLTP(image,scale,row,col,thres):
    
    ltpmat1 = np.zeros(shape=(r-2,c-2),dtype=np.uint8)
    ltpmat2 = np.zeros(shape=(r-2,c-2),dtype=np.uint8)

    for i in range(1,row-1):
        for j in range(1,col-1):
            window = image[i-1:i+2,j-1:j+2]
            a=window[1,1]-thres
            b=window[1,1]+thres
            binary1=window>=b
            binary2=window<=a
            ltpmat1[i-1,j-1] = (sum(sum(binary1*scale)))
            ltpmat2[i-1,j-1] = (sum(sum(binary2*scale)))
    
    return ltpmat1,ltpmat2

# %%
def histogram(image,bins=256):
    hist = np.zeros(shape=bins)
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            hist[image[i,j]]+=1
    
    return hist

# %%
def SLTP_feature_vector(image):
    scale = np.array([[2,0,1],[0,0,0],[4,0,8]],dtype=np.uint8)
    (r,c) = image.shape
    threshold=5
    ltpmat1,ltpmat2 = SLTP(image,scale,r,c,threshold)
    ltph1 = histogram(ltpmat1,16)
    ltph2 = histogram(ltpmat2,16)
    return np.concatenate((ltph1,ltph2))

# %%
image = io.imread('orl_faces\\s01\\1.pgm')
scale = np.array([[2,0,1],[0,0,0],[4,0,8]],dtype=np.uint8)
(r,c) = image.shape
threshold=5
ltp_image1,ltp_image2=SLTP(image,scale,r,c,threshold)
hist1 = histogram(ltp_image1,16)
hist2 = histogram(ltp_image2,16)

fig = plt.figure(figsize=(15,15))
gs=GridSpec(3,3)

ax1=fig.add_subplot(gs[0,0])
ax2=fig.add_subplot(gs[0,1])
ax3=fig.add_subplot(gs[0,2])
ax4=fig.add_subplot(gs[1,:])
ax5=fig.add_subplot(gs[2,:])


ax1.set_title('Gray Scale Image')
ax1.imshow(image,cmap='gray')
ax1.set_yticklabels([])
ax1.set_xticklabels([])

ax2.set_title('LTP Image (Upper matrix)')
ax2.imshow(ltp_image1,cmap='gray')
ax2.set_yticklabels([])
ax2.set_xticklabels([])

ax3.set_title('LTP Image (Lower matrix)')
ax3.imshow(ltp_image2,cmap='gray')
ax3.set_yticklabels([])
ax3.set_xticklabels([])

ax4.bar(range(0,16),hist1)
ax4.set_xlabel('Intensity Values')
ax4.set_ylabel('Frequency')
ax4.set_xticks(np.arange(0,16))
ax4.set_title('LTP Histogram (Upper matrix)')

ax5.bar(range(0,16),hist2)
ax5.set_xlabel('Intensity Values')
ax5.set_ylabel('Frequency')
ax5.set_xticks(np.arange(0,16))
ax5.set_title('LTP Histogram (Lower matrix)')

plt.show()

# %%
sltp_feature_matrix = []
k=1
for img_file in glob.glob("orl_faces\\**\\*.pgm"):
    print("processing image : ",k,": ",img_file)
    image = io.imread(img_file)
    sltp_feature_matrix.append(SLTP_feature_vector(image))
    k+=1
    
np.savetxt("CSV\\orl_faces_SLTP_FeatureMatrix.csv",sltp_feature_matrix,fmt='%f',delimiter=",")
# Out:
# processing image :  1 :  orl_faces\s01\0.pgm
# processing image :  2 :  orl_faces\s01\1.pgm
# processing image :  3 :  orl_faces\s01\2.pgm
# processing image :  4 :  orl_faces\s01\3.pgm
# processing image :  5 :  orl_faces\s01\4.pgm
# processing image :  6 :  orl_faces\s01\5.pgm
# processing image :  7 :  orl_faces\s01\6.pgm
# processing image :  8 :  orl_faces\s01\7.pgm
# processing image :  9 :  orl_faces\s01\8.pgm
# processing image :  10 :  orl_faces\s01\9.pgm
# processing image :  11 :  orl_faces\s02\0.pgm
# processing image :  12 :  orl_faces\s02\1.pgm
# processing image :  13 :  orl_faces\s02\2.pgm
# processing image :  14 :  orl_faces\s02\3.pgm
# processing image :  15 :  orl_faces\s02\4.pgm
# processing image :  16 :  orl_faces\s02\5.pgm
# processing image :  17 :  orl_faces\s02\6.pgm
# processing image :  18 :  orl_faces\s02\7.pgm
# processing image :  19 :  orl_faces\s02\8.pgm
# processing image :  20 :  orl_faces\s02\9.pgm
# processing image :  21 :  orl_faces\s03\0.pgm
# processing image :  22 :  orl_faces\s03\1.pgm
# processing image :  23 :  orl_faces\s03\2.pgm
# processing image :  24 :  orl_faces\s03\3.pgm
# processing image :  25 :  orl_faces\s03\4.pgm
# processing image :  26 :  orl_faces\s03\5.pgm
# processing image :  27 :  orl_faces\s03\6.pgm
# processing image :  28 :  orl_faces\s03\7.pgm
# processing image :  29 :  orl_faces\s03\8.pgm
# processing image :  30 :  orl_faces\s03\9.pgm
# processing image :  31 :  orl_faces\s04\0.pgm
# processing image :  32 :  orl_faces\s04\1.pgm
# processing image :  33 :  orl_faces\s04\2.pgm
# processing image :  34 :  orl_faces\s04\3.pgm
# processing image :  35 :  orl_faces\s04\4.pgm
# processing image :  36 :  orl_faces\s04\5.pgm
# processing image :  37 :  orl_faces\s04\6.pgm
# processing image :  38 :  orl_faces\s04\7.pgm
# processing image :  39 :  orl_faces\s04\8.pgm
# processing image :  40 :  orl_faces\s04\9.pgm
# processing image :  41 :  orl_faces\s05\0.pgm
# processing image :  42 :  orl_faces\s05\1.pgm
# processing image :  43 :  orl_faces\s05\2.pgm
# processing image :  44 :  orl_faces\s05\3.pgm
# processing image :  45 :  orl_faces\s05\4.pgm
# processing image :  46 :  orl_faces\s05\5.pgm
# processing image :  47 :  orl_faces\s05\6.pgm
# processing image :  48 :  orl_faces\s05\7.pgm
# processing image :  49 :  orl_faces\s05\8.pgm
# processing image :  50 :  orl_faces\s05\9.pgm
# processing image :  51 :  orl_faces\s06\0.pgm
# processing image :  52 :  orl_faces\s06\1.pgm
# processing image :  53 :  orl_faces\s06\2.pgm
# processing image :  54 :  orl_faces\s06\3.pgm
# processing image :  55 :  orl_faces\s06\4.pgm
# processing image :  56 :  orl_faces\s06\5.pgm
# processing image :  57 :  orl_faces\s06\6.pgm
# processing image :  58 :  orl_faces\s06\7.pgm
# processing image :  59 :  orl_faces\s06\8.pgm
# processing image :  60 :  orl_faces\s06\9.pgm
# processing image :  61 :  orl_faces\s07\0.pgm
# processing image :  62 :  orl_faces\s07\1.pgm
# processing image :  63 :  orl_faces\s07\2.pgm
# processing image :  64 :  orl_faces\s07\3.pgm
# processing image :  65 :  orl_faces\s07\4.pgm
# processing image :  66 :  orl_faces\s07\5.pgm
# processing image :  67 :  orl_faces\s07\6.pgm
# processing image :  68 :  orl_faces\s07\7.pgm
# processing image :  69 :  orl_faces\s07\8.pgm
# processing image :  70 :  orl_faces\s07\9.pgm
# processing image :  71 :  orl_faces\s08\0.pgm
# processing image :  72 :  orl_faces\s08\1.pgm
# processing image :  73 :  orl_faces\s08\2.pgm
# processing image :  74 :  orl_faces\s08\3.pgm
# processing image :  75 :  orl_faces\s08\4.pgm
# processing image :  76 :  orl_faces\s08\5.pgm
# processing image :  77 :  orl_faces\s08\6.pgm
# processing image :  78 :  orl_faces\s08\7.pgm
# processing image :  79 :  orl_faces\s08\8.pgm
# processing image :  80 :  orl_faces\s08\9.pgm
# processing image :  81 :  orl_faces\s09\0.pgm
# processing image :  82 :  orl_faces\s09\1.pgm
# processing image :  83 :  orl_faces\s09\2.pgm
# processing image :  84 :  orl_faces\s09\3.pgm
# processing image :  85 :  orl_faces\s09\4.pgm
# processing image :  86 :  orl_faces\s09\5.pgm
# processing image :  87 :  orl_faces\s09\6.pgm
# processing image :  88 :  orl_faces\s09\7.pgm
# processing image :  89 :  orl_faces\s09\8.pgm
# processing image :  90 :  orl_faces\s09\9.pgm
# processing image :  91 :  orl_faces\s10\0.pgm
# processing image :  92 :  orl_faces\s10\1.pgm
# processing image :  93 :  orl_faces\s10\2.pgm
# processing image :  94 :  orl_faces\s10\3.pgm
# processing image :  95 :  orl_faces\s10\4.pgm
# processing image :  96 :  orl_faces\s10\5.pgm
# processing image :  97 :  orl_faces\s10\6.pgm
# processing image :  98 :  orl_faces\s10\7.pgm
# processing image :  99 :  orl_faces\s10\8.pgm
# processing image :  100 :  orl_faces\s10\9.pgm
# processing image :  101 :  orl_faces\s11\0.pgm
# processing image :  102 :  orl_faces\s11\1.pgm
# processing image :  103 :  orl_faces\s11\2.pgm
# processing image :  104 :  orl_faces\s11\3.pgm
# processing image :  105 :  orl_faces\s11\4.pgm
# processing image :  106 :  orl_faces\s11\5.pgm
# processing image :  107 :  orl_faces\s11\6.pgm
# processing image :  108 :  orl_faces\s11\7.pgm
# processing image :  109 :  orl_faces\s11\8.pgm
# processing image :  110 :  orl_faces\s11\9.pgm
# processing image :  111 :  orl_faces\s12\0.pgm
# processing image :  112 :  orl_faces\s12\1.pgm
# processing image :  113 :  orl_faces\s12\2.pgm
# processing image :  114 :  orl_faces\s12\3.pgm
# processing image :  115 :  orl_faces\s12\4.pgm
# processing image :  116 :  orl_faces\s12\5.pgm
# processing image :  117 :  orl_faces\s12\6.pgm
# processing image :  118 :  orl_faces\s12\7.pgm
# processing image :  119 :  orl_faces\s12\8.pgm
# processing image :  120 :  orl_faces\s12\9.pgm
# processing image :  121 :  orl_faces\s13\0.pgm
# processing image :  122 :  orl_faces\s13\1.pgm
# processing image :  123 :  orl_faces\s13\2.pgm
# processing image :  124 :  orl_faces\s13\3.pgm
# processing image :  125 :  orl_faces\s13\4.pgm
# processing image :  126 :  orl_faces\s13\5.pgm
# processing image :  127 :  orl_faces\s13\6.pgm
# processing image :  128 :  orl_faces\s13\7.pgm
# processing image :  129 :  orl_faces\s13\8.pgm
# processing image :  130 :  orl_faces\s13\9.pgm
# processing image :  131 :  orl_faces\s14\0.pgm
# processing image :  132 :  orl_faces\s14\1.pgm
# processing image :  133 :  orl_faces\s14\2.pgm
# processing image :  134 :  orl_faces\s14\3.pgm
# processing image :  135 :  orl_faces\s14\4.pgm
# processing image :  136 :  orl_faces\s14\5.pgm
# processing image :  137 :  orl_faces\s14\6.pgm
# processing image :  138 :  orl_faces\s14\7.pgm
# processing image :  139 :  orl_faces\s14\8.pgm
# processing image :  140 :  orl_faces\s14\9.pgm
# processing image :  141 :  orl_faces\s15\0.pgm
# processing image :  142 :  orl_faces\s15\1.pgm
# processing image :  143 :  orl_faces\s15\2.pgm
# processing image :  144 :  orl_faces\s15\3.pgm
# processing image :  145 :  orl_faces\s15\4.pgm
# processing image :  146 :  orl_faces\s15\5.pgm
# processing image :  147 :  orl_faces\s15\6.pgm
# processing image :  148 :  orl_faces\s15\7.pgm
# processing image :  149 :  orl_faces\s15\8.pgm
# processing image :  150 :  orl_faces\s15\9.pgm
# processing image :  151 :  orl_faces\s16\0.pgm
# processing image :  152 :  orl_faces\s16\1.pgm
# processing image :  153 :  orl_faces\s16\2.pgm
# processing image :  154 :  orl_faces\s16\3.pgm
# processing image :  155 :  orl_faces\s16\4.pgm
# processing image :  156 :  orl_faces\s16\5.pgm
# processing image :  157 :  orl_faces\s16\6.pgm
# processing image :  158 :  orl_faces\s16\7.pgm
# processing image :  159 :  orl_faces\s16\8.pgm
# processing image :  160 :  orl_faces\s16\9.pgm
# processing image :  161 :  orl_faces\s17\0.pgm
# processing image :  162 :  orl_faces\s17\1.pgm
# processing image :  163 :  orl_faces\s17\2.pgm
# processing image :  164 :  orl_faces\s17\3.pgm
# processing image :  165 :  orl_faces\s17\4.pgm
# processing image :  166 :  orl_faces\s17\5.pgm
# processing image :  167 :  orl_faces\s17\6.pgm
# processing image :  168 :  orl_faces\s17\7.pgm
# processing image :  169 :  orl_faces\s17\8.pgm
# processing image :  170 :  orl_faces\s17\9.pgm
# processing image :  171 :  orl_faces\s18\0.pgm
# processing image :  172 :  orl_faces\s18\1.pgm
# processing image :  173 :  orl_faces\s18\2.pgm
# processing image :  174 :  orl_faces\s18\3.pgm
# processing image :  175 :  orl_faces\s18\4.pgm
# processing image :  176 :  orl_faces\s18\5.pgm
# processing image :  177 :  orl_faces\s18\6.pgm
# processing image :  178 :  orl_faces\s18\7.pgm
# processing image :  179 :  orl_faces\s18\8.pgm
# processing image :  180 :  orl_faces\s18\9.pgm
# processing image :  181 :  orl_faces\s19\0.pgm
# processing image :  182 :  orl_faces\s19\1.pgm
# processing image :  183 :  orl_faces\s19\2.pgm
# processing image :  184 :  orl_faces\s19\3.pgm
# processing image :  185 :  orl_faces\s19\4.pgm
# processing image :  186 :  orl_faces\s19\5.pgm
# processing image :  187 :  orl_faces\s19\6.pgm
# processing image :  188 :  orl_faces\s19\7.pgm
# processing image :  189 :  orl_faces\s19\8.pgm
# processing image :  190 :  orl_faces\s19\9.pgm
# processing image :  191 :  orl_faces\s20\0.pgm
# processing image :  192 :  orl_faces\s20\1.pgm
# processing image :  193 :  orl_faces\s20\2.pgm
# processing image :  194 :  orl_faces\s20\3.pgm
# processing image :  195 :  orl_faces\s20\4.pgm
# processing image :  196 :  orl_faces\s20\5.pgm
# processing image :  197 :  orl_faces\s20\6.pgm
# processing image :  198 :  orl_faces\s20\7.pgm
# processing image :  199 :  orl_faces\s20\8.pgm
# processing image :  200 :  orl_faces\s20\9.pgm
# processing image :  201 :  orl_faces\s21\0.pgm
# processing image :  202 :  orl_faces\s21\1.pgm
# processing image :  203 :  orl_faces\s21\2.pgm
# processing image :  204 :  orl_faces\s21\3.pgm
# processing image :  205 :  orl_faces\s21\4.pgm
# processing image :  206 :  orl_faces\s21\5.pgm
# processing image :  207 :  orl_faces\s21\6.pgm
# processing image :  208 :  orl_faces\s21\7.pgm
# processing image :  209 :  orl_faces\s21\8.pgm
# processing image :  210 :  orl_faces\s21\9.pgm
# processing image :  211 :  orl_faces\s22\0.pgm
# processing image :  212 :  orl_faces\s22\1.pgm
# processing image :  213 :  orl_faces\s22\2.pgm
# processing image :  214 :  orl_faces\s22\3.pgm
# processing image :  215 :  orl_faces\s22\4.pgm
# processing image :  216 :  orl_faces\s22\5.pgm
# processing image :  217 :  orl_faces\s22\6.pgm
# processing image :  218 :  orl_faces\s22\7.pgm
# processing image :  219 :  orl_faces\s22\8.pgm
# processing image :  220 :  orl_faces\s22\9.pgm
# processing image :  221 :  orl_faces\s23\0.pgm
# processing image :  222 :  orl_faces\s23\1.pgm
# processing image :  223 :  orl_faces\s23\2.pgm
# processing image :  224 :  orl_faces\s23\3.pgm
# processing image :  225 :  orl_faces\s23\4.pgm
# processing image :  226 :  orl_faces\s23\5.pgm
# processing image :  227 :  orl_faces\s23\6.pgm
# processing image :  228 :  orl_faces\s23\7.pgm
# processing image :  229 :  orl_faces\s23\8.pgm
# processing image :  230 :  orl_faces\s23\9.pgm
# processing image :  231 :  orl_faces\s24\0.pgm
# processing image :  232 :  orl_faces\s24\1.pgm
# processing image :  233 :  orl_faces\s24\2.pgm
# processing image :  234 :  orl_faces\s24\3.pgm
# processing image :  235 :  orl_faces\s24\4.pgm
# processing image :  236 :  orl_faces\s24\5.pgm
# processing image :  237 :  orl_faces\s24\6.pgm
# processing image :  238 :  orl_faces\s24\7.pgm
# processing image :  239 :  orl_faces\s24\8.pgm
# processing image :  240 :  orl_faces\s24\9.pgm
# processing image :  241 :  orl_faces\s25\0.pgm
# processing image :  242 :  orl_faces\s25\1.pgm
# processing image :  243 :  orl_faces\s25\2.pgm
# processing image :  244 :  orl_faces\s25\3.pgm
# processing image :  245 :  orl_faces\s25\4.pgm
# processing image :  246 :  orl_faces\s25\5.pgm
# processing image :  247 :  orl_faces\s25\6.pgm
# processing image :  248 :  orl_faces\s25\7.pgm
# processing image :  249 :  orl_faces\s25\8.pgm
# processing image :  250 :  orl_faces\s25\9.pgm
# processing image :  251 :  orl_faces\s26\0.pgm
# processing image :  252 :  orl_faces\s26\1.pgm
# processing image :  253 :  orl_faces\s26\2.pgm
# processing image :  254 :  orl_faces\s26\3.pgm
# processing image :  255 :  orl_faces\s26\4.pgm
# processing image :  256 :  orl_faces\s26\5.pgm
# processing image :  257 :  orl_faces\s26\6.pgm
# processing image :  258 :  orl_faces\s26\7.pgm
# processing image :  259 :  orl_faces\s26\8.pgm
# processing image :  260 :  orl_faces\s26\9.pgm
# processing image :  261 :  orl_faces\s27\0.pgm
# processing image :  262 :  orl_faces\s27\1.pgm
# processing image :  263 :  orl_faces\s27\2.pgm
# processing image :  264 :  orl_faces\s27\3.pgm
# processing image :  265 :  orl_faces\s27\4.pgm
# processing image :  266 :  orl_faces\s27\5.pgm
# processing image :  267 :  orl_faces\s27\6.pgm
# processing image :  268 :  orl_faces\s27\7.pgm
# processing image :  269 :  orl_faces\s27\8.pgm
# processing image :  270 :  orl_faces\s27\9.pgm
# processing image :  271 :  orl_faces\s28\0.pgm
# processing image :  272 :  orl_faces\s28\1.pgm
# processing image :  273 :  orl_faces\s28\2.pgm
# processing image :  274 :  orl_faces\s28\3.pgm
# processing image :  275 :  orl_faces\s28\4.pgm
# processing image :  276 :  orl_faces\s28\5.pgm
# processing image :  277 :  orl_faces\s28\6.pgm
# processing image :  278 :  orl_faces\s28\7.pgm
# processing image :  279 :  orl_faces\s28\8.pgm
# processing image :  280 :  orl_faces\s28\9.pgm
# processing image :  281 :  orl_faces\s29\0.pgm
# processing image :  282 :  orl_faces\s29\1.pgm
# processing image :  283 :  orl_faces\s29\2.pgm
# processing image :  284 :  orl_faces\s29\3.pgm
# processing image :  285 :  orl_faces\s29\4.pgm
# processing image :  286 :  orl_faces\s29\5.pgm
# processing image :  287 :  orl_faces\s29\6.pgm
# processing image :  288 :  orl_faces\s29\7.pgm
# processing image :  289 :  orl_faces\s29\8.pgm
# processing image :  290 :  orl_faces\s29\9.pgm
# processing image :  291 :  orl_faces\s30\0.pgm
# processing image :  292 :  orl_faces\s30\1.pgm
# processing image :  293 :  orl_faces\s30\2.pgm
# processing image :  294 :  orl_faces\s30\3.pgm
# processing image :  295 :  orl_faces\s30\4.pgm
# processing image :  296 :  orl_faces\s30\5.pgm
# processing image :  297 :  orl_faces\s30\6.pgm
# processing image :  298 :  orl_faces\s30\7.pgm
# processing image :  299 :  orl_faces\s30\8.pgm
# processing image :  300 :  orl_faces\s30\9.pgm
# processing image :  301 :  orl_faces\s31\0.pgm
# processing image :  302 :  orl_faces\s31\1.pgm
# processing image :  303 :  orl_faces\s31\2.pgm
# processing image :  304 :  orl_faces\s31\3.pgm
# processing image :  305 :  orl_faces\s31\4.pgm
# processing image :  306 :  orl_faces\s31\5.pgm
# processing image :  307 :  orl_faces\s31\6.pgm
# processing image :  308 :  orl_faces\s31\7.pgm
# processing image :  309 :  orl_faces\s31\8.pgm
# processing image :  310 :  orl_faces\s31\9.pgm
# processing image :  311 :  orl_faces\s32\0.pgm
# processing image :  312 :  orl_faces\s32\1.pgm
# processing image :  313 :  orl_faces\s32\2.pgm
# processing image :  314 :  orl_faces\s32\3.pgm
# processing image :  315 :  orl_faces\s32\4.pgm
# processing image :  316 :  orl_faces\s32\5.pgm
# processing image :  317 :  orl_faces\s32\6.pgm
# processing image :  318 :  orl_faces\s32\7.pgm
# processing image :  319 :  orl_faces\s32\8.pgm
# processing image :  320 :  orl_faces\s32\9.pgm
# processing image :  321 :  orl_faces\s33\0.pgm
# processing image :  322 :  orl_faces\s33\1.pgm
# processing image :  323 :  orl_faces\s33\2.pgm
# processing image :  324 :  orl_faces\s33\3.pgm
# processing image :  325 :  orl_faces\s33\4.pgm
# processing image :  326 :  orl_faces\s33\5.pgm
# processing image :  327 :  orl_faces\s33\6.pgm
# processing image :  328 :  orl_faces\s33\7.pgm
# processing image :  329 :  orl_faces\s33\8.pgm
# processing image :  330 :  orl_faces\s33\9.pgm
# processing image :  331 :  orl_faces\s34\0.pgm
# processing image :  332 :  orl_faces\s34\1.pgm
# processing image :  333 :  orl_faces\s34\2.pgm
# processing image :  334 :  orl_faces\s34\3.pgm
# processing image :  335 :  orl_faces\s34\4.pgm
# processing image :  336 :  orl_faces\s34\5.pgm
# processing image :  337 :  orl_faces\s34\6.pgm
# processing image :  338 :  orl_faces\s34\7.pgm
# processing image :  339 :  orl_faces\s34\8.pgm
# processing image :  340 :  orl_faces\s34\9.pgm
# processing image :  341 :  orl_faces\s35\0.pgm
# processing image :  342 :  orl_faces\s35\1.pgm
# processing image :  343 :  orl_faces\s35\2.pgm
# processing image :  344 :  orl_faces\s35\3.pgm
# processing image :  345 :  orl_faces\s35\4.pgm
# processing image :  346 :  orl_faces\s35\5.pgm
# processing image :  347 :  orl_faces\s35\6.pgm
# processing image :  348 :  orl_faces\s35\7.pgm
# processing image :  349 :  orl_faces\s35\8.pgm
# processing image :  350 :  orl_faces\s35\9.pgm
# processing image :  351 :  orl_faces\s36\0.pgm
# processing image :  352 :  orl_faces\s36\1.pgm
# processing image :  353 :  orl_faces\s36\2.pgm
# processing image :  354 :  orl_faces\s36\3.pgm
# processing image :  355 :  orl_faces\s36\4.pgm
# processing image :  356 :  orl_faces\s36\5.pgm
# processing image :  357 :  orl_faces\s36\6.pgm
# processing image :  358 :  orl_faces\s36\7.pgm
# processing image :  359 :  orl_faces\s36\8.pgm
# processing image :  360 :  orl_faces\s36\9.pgm
# processing image :  361 :  orl_faces\s37\0.pgm
# processing image :  362 :  orl_faces\s37\1.pgm
# processing image :  363 :  orl_faces\s37\2.pgm
# processing image :  364 :  orl_faces\s37\3.pgm
# processing image :  365 :  orl_faces\s37\4.pgm
# processing image :  366 :  orl_faces\s37\5.pgm
# processing image :  367 :  orl_faces\s37\6.pgm
# processing image :  368 :  orl_faces\s37\7.pgm
# processing image :  369 :  orl_faces\s37\8.pgm
# processing image :  370 :  orl_faces\s37\9.pgm
# processing image :  371 :  orl_faces\s38\0.pgm
# processing image :  372 :  orl_faces\s38\1.pgm
# processing image :  373 :  orl_faces\s38\2.pgm
# processing image :  374 :  orl_faces\s38\3.pgm
# processing image :  375 :  orl_faces\s38\4.pgm
# processing image :  376 :  orl_faces\s38\5.pgm
# processing image :  377 :  orl_faces\s38\6.pgm
# processing image :  378 :  orl_faces\s38\7.pgm
# processing image :  379 :  orl_faces\s38\8.pgm
# processing image :  380 :  orl_faces\s38\9.pgm
# processing image :  381 :  orl_faces\s39\0.pgm
# processing image :  382 :  orl_faces\s39\1.pgm
# processing image :  383 :  orl_faces\s39\2.pgm
# processing image :  384 :  orl_faces\s39\3.pgm
# processing image :  385 :  orl_faces\s39\4.pgm
# processing image :  386 :  orl_faces\s39\5.pgm
# processing image :  387 :  orl_faces\s39\6.pgm
# processing image :  388 :  orl_faces\s39\7.pgm
# processing image :  389 :  orl_faces\s39\8.pgm
# processing image :  390 :  orl_faces\s39\9.pgm
# processing image :  391 :  orl_faces\s40\0.pgm
# processing image :  392 :  orl_faces\s40\1.pgm
# processing image :  393 :  orl_faces\s40\2.pgm
# processing image :  394 :  orl_faces\s40\3.pgm
# processing image :  395 :  orl_faces\s40\4.pgm
# processing image :  396 :  orl_faces\s40\5.pgm
# processing image :  397 :  orl_faces\s40\6.pgm
# processing image :  398 :  orl_faces\s40\7.pgm
# processing image :  399 :  orl_faces\s40\8.pgm
# processing image :  400 :  orl_faces\s40\9.pgm

# %%
def cityBlockDistance(feature_matrix):
    (row,col)=np.shape(feature_matrix)
    city_block_distance_matrix = np.zeros(shape=(row,row),dtype=np.float)
    for i in range(row):
        for j in range(i+1,row):
            city_block_distance_matrix[i,j] = city_block_distance_matrix[j,i] = sum(np.abs(feature_matrix[i]-feature_matrix[j]))
    return city_block_distance_matrix

# %%
def euclideanDistance(feature_matrix):
    (row,col)=np.shape(feature_matrix)
    euclidean_distance_matrix = np.zeros(shape=(row,row),dtype=np.float)
    for i in range(row):
        for j in range(i+1,row):
            euclidean_distance_matrix[i,j] = euclidean_distance_matrix[j,i] = math.sqrt(sum(np.square(feature_matrix[i]-feature_matrix[j])))
    return euclidean_distance_matrix

# %%
def d1Distance(feature_matrix):
    (row,col)=np.shape(feature_matrix)
    d1_distance_matrix = np.zeros(shape=(row,row),dtype=np.float)
    for i in range(row):
        for j in range(i+1,row):
            d1_distance_matrix[i,j] = d1_distance_matrix[j,i] = sum(abs((feature_matrix[i]-feature_matrix[j])/(1+feature_matrix[i]+feature_matrix[j])))
    return d1_distance_matrix

# %%
city_block_distance_matrix = cityBlockDistance(np.array(sltp_feature_matrix,dtype=np.double))
euclidean_distance_matrix = euclideanDistance(np.array(sltp_feature_matrix,dtype=np.double))
d1_distance_matrix = d1Distance(np.array(sltp_feature_matrix,dtype=np.double))

np.savetxt("CSV\\sltp_distance\\orl_faces_sltp_CityBlockDistanceMatrix.csv",city_block_distance_matrix,fmt='%f',delimiter=",")
np.savetxt("CSV\\sltp_distance\\orl_faces_sltp_EuclideanDistanceMatrix.csv",euclidean_distance_matrix,fmt='%f',delimiter=",")
np.savetxt("CSV\\sltp_distance\\orl_faces_sltp_D1DistanceMatrix.csv",d1_distance_matrix,fmt='%f',delimiter=",")

# %%
def averagePrecision(distance_matrix,classes,retrive_images,relevant_images_DB):
    
    class_precision = [0]*classes
    
    i=0
    for distmat in distance_matrix:
        relevant_images=sum(np.floor(np.argsort(distmat)[:retrive_images]/relevant_images_DB)==math.floor(i/relevant_images_DB))
        class_precision[math.floor(i/relevant_images_DB)]+=relevant_images/retrive_images
        l=i
        i=i+1;
        if math.floor(i/relevant_images_DB)!=math.floor(l/relevant_images_DB):
            class_precision[math.floor(l/relevant_images_DB)]/=relevant_images_DB
            
    class_precision*=100
    average_precision = sum(class_precision)/classes
    
    return class_precision,average_precision

# %%
def averageRecall(distance_matrix,classes,retrive_images,relevant_images_DB):
    
    class_recall = [0]*classes
    
    i=0
    for distmat in distance_matrix:
        relevant_images=sum(np.floor(np.argsort(distmat)[:retrive_images]/relevant_images_DB)==math.floor(i/relevant_images_DB))
        class_recall[math.floor(i/relevant_images_DB)]+=relevant_images/relevant_images_DB
        l=i
        i=i+1;
        if math.floor(i/relevant_images_DB)!=math.floor(l/relevant_images_DB):
            class_recall[math.floor(l/relevant_images_DB)]/=relevant_images_DB
    class_recall*=100
    average_recall = sum(class_recall)/classes
    return class_recall,average_recall

# %%
classes = 40
retrive_images = 30
relevant_images_DB = 10

city_block_class_precision,city_block_average_precision = averagePrecision(city_block_distance_matrix,classes,retrive_images,relevant_images_DB)
city_block_class_recall,city_block_average_recall = averageRecall(city_block_distance_matrix,classes,retrive_images,relevant_images_DB)

euclidean_class_precision,euclidean_average_precision = averagePrecision(euclidean_distance_matrix,classes,retrive_images,relevant_images_DB)
euclidean_class_recall,euclidean_average_recall = averageRecall(euclidean_distance_matrix,classes,retrive_images,relevant_images_DB)

d1_class_precision,d1_average_precision = averagePrecision(d1_distance_matrix,classes,retrive_images,relevant_images_DB)
d1_class_recall,d1_average_recall = averageRecall(d1_distance_matrix,classes,retrive_images,relevant_images_DB)
print('City Block Average Precision: '+str(city_block_average_precision)+'%')
print('City Block Average Recall: '+str(city_block_average_recall)+'%')
print('Euclidean Average Precision: '+str(euclidean_average_precision)+'%')
print('Euclidean Average Recall: '+str(euclidean_average_recall)+'%')
print('D1 Average Precision: '+str(d1_average_precision)+'%')
print('D1 Average Recall: '+str(d1_average_recall)+'%')
# Out:
# City Block Average Precision: 22.658333333333278%
# City Block Average Recall: 67.97500000000056%
# Euclidean Average Precision: 21.06666666666618%
# Euclidean Average Recall: 63.200000000000024%
# D1 Average Precision: 23.35833333333351%
# D1 Average Recall: 70.07499999999969%

# %%
n_groups = 40
 
fig, ax = plt.subplots(figsize=(15, 5))

index = np.arange(n_groups)
bar_width = 0.25
opacity = 0.8
 
rects1 = plt.bar(index, city_block_class_precision[0:40], bar_width, alpha=opacity, color='b', label='City Block Distance')
rects2 = plt.bar(index + bar_width, euclidean_class_precision[0:40], bar_width, alpha=opacity, color='y', label='Euclidean Distance')
rects3 = plt.bar(index + 2*bar_width, d1_class_precision[0:40], bar_width, alpha=opacity, color='r', label='D1 Distance')
 
plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Class wise precisions for different distances')
plt.xticks(index + bar_width, range(1,41))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
n_groups = 40
 
fig, ax = plt.subplots(figsize=(15, 5))

index = np.arange(n_groups)
bar_width = 0.25
opacity = 0.8
 
rects1 = plt.bar(index, city_block_class_recall[0:40], bar_width, alpha=opacity, color='b', label='City Block Distance')
rects2 = plt.bar(index + bar_width, euclidean_class_recall[0:40], bar_width, alpha=opacity, color='y', label='Euclidean Distance')
rects3 = plt.bar(index + 2*bar_width, d1_class_recall[0:40], bar_width, alpha=opacity, color='r', label='D1 Distance')
 
plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Class wise recall rate for different distances')
plt.xticks(index + bar_width, range(1,41))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
distances = ('City Block','Euclidean','D1')
y_pos = np.arange(len(distances))
average_precisions = [city_block_average_precision,euclidean_average_precision,d1_average_precision]
plt.figure(figsize=(10,5))
plt.bar(y_pos, average_precisions,0.2 ,align='center')
plt.xticks(y_pos, distances)
plt.ylabel('Average Precision')
plt.title('Comparision of average precisions using different distance formulae')
plt.tight_layout()
plt.show()

# %%
average_recalls = [city_block_average_recall,euclidean_average_recall,d1_average_recall]
plt.figure(figsize=(10,5))
plt.bar(y_pos, average_recalls,0.2 ,align='center')
plt.xticks(y_pos, distances)
plt.ylabel('Average Recall Rate')
plt.title('Comparision of average recall rate using different distance formulae')
plt.tight_layout()
plt.show()

# %%
city_block_average_precisions = []
city_block_average_recalls = []
euclidean_average_precisions = []
euclidean_average_recalls = []
d1_average_precisions = []
d1_average_recalls = []
for retrive_images in range(10,101,10):
    city_block_average_precisions.append(averagePrecision(city_block_distance_matrix,classes,retrive_images,relevant_images_DB)[1])
    city_block_average_recalls.append(averageRecall(city_block_distance_matrix,classes,retrive_images,relevant_images_DB)[1])
    euclidean_average_precisions.append(averagePrecision(euclidean_distance_matrix,classes,retrive_images,relevant_images_DB)[1])
    euclidean_average_recalls.append(averageRecall(euclidean_distance_matrix,classes,retrive_images,relevant_images_DB)[1])
    d1_average_precisions.append(averagePrecision(d1_distance_matrix,classes,retrive_images,relevant_images_DB)[1])
    d1_average_recalls.append(averageRecall(d1_distance_matrix,classes,retrive_images,relevant_images_DB)[1])

# %%
fig = plt.figure(figsize=(15,8))
gs=GridSpec(1,2)
index = range(10,101,10)
ax1=fig.add_subplot(gs[0,0])
ax2=fig.add_subplot(gs[0,1])

ax1.plot(index,city_block_average_precisions,'-g.',label='City Block')
ax1.plot(index,euclidean_average_precisions,'-r.',label='Euclidean')
ax1.plot(index,d1_average_precisions,'-b.',label='D1')
ax1.set_xlabel('Number of retrive images')
ax1.set_ylabel('Precision')
ax1.set_title('Average Precision for different numbers of retrival images')
ax1.set_xticks(range(10,101,10))
ax1.set_yticks(np.arange(math.floor(min(min(d1_average_precisions),min(euclidean_average_precisions),min(city_block_average_precisions))), max(max(d1_average_precisions),max(euclidean_average_precisions),max(city_block_average_precisions))+1, 5.0))
ax1.grid()
ax1.legend()

ax2.plot(index,city_block_average_recalls,'-g.',label='City Block')
ax2.plot(index,euclidean_average_recalls,'-r.',label='Euclidean')
ax2.plot(index,d1_average_recalls,'-b.',label='D1')
ax2.set_xlabel('Number of retrive images')
ax2.set_ylabel('Recall Rate')
ax2.set_title('Average Recall Rate for different numbers of retrival images')
ax2.set_xticks(range(10,101,10))
ax2.set_yticks(np.arange(math.floor(min(min(d1_average_recalls),min(euclidean_average_recalls),min(city_block_average_recalls))), max(max(d1_average_recalls),max(euclidean_average_recalls),max(city_block_average_recalls))+1, 5.0))
ax2.grid()
ax2.legend()

plt.show()

# %%
query=int(input("Enter an image: (0-399):"))
# Out:
# Enter an image: (0-399):223

# %%
queryclass=math.floor(query/10)
queryimg=query%10
queryimage=io.imread("orl_faces\\s"+str(queryclass+1).zfill(2)+"\\"+str(queryimg)+".pgm")

query_sltp_feature=SLTP_feature_vector(queryimage)

sltp_feature_matrix=np.array(sltp_feature_matrix,dtype=np.double)
distance_matrix_city_block=np.zeros(shape=(sltp_feature_matrix.shape[0]),dtype=np.double)
for i in range(sltp_feature_matrix.shape[0]):
    distance_matrix_city_block[i]=sum(np.abs(query_sltp_feature-sltp_feature_matrix[i]))

best=8
bestimgs=np.argsort(distance_matrix_city_block)[:best]
classes=np.floor(bestimgs/10).astype(np.intc)+1
imgs=bestimgs%10

retrieve_images=[]
for i in range(best):
    image=io.imread("orl_faces\\s"+str(classes[i]).zfill(2)+"\\"+str(imgs[i])+".pgm")
    retrieve_images.append(image)
    
print("User Given Image:-")

fig = plt.figure(figsize=(8,8))
gs=GridSpec(int(math.floor(best/4))+1,4)

ax1=fig.add_subplot(gs[0,:])
ax1.imshow(queryimage,cmap='gray')
ax1.set_yticklabels([])
ax1.set_xticklabels([])

for i in range(best):
    ax=fig.add_subplot(gs[math.floor(i/4)+1,i%4])
    ax.imshow(retrieve_images[i],cmap='gray')
    ax.set_yticklabels([])
    ax.set_xticklabels([])

fig.show()
# Out:
# User Given Image:-
# C:\Users\Supreet\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
queryclass=math.floor(query/10)
queryimg=query%10
queryimage=io.imread("orl_faces\\s"+str(queryclass+1).zfill(2)+"\\"+str(queryimg)+".pgm")

query_sltp_feature=SLTP_feature_vector(queryimage)

sltp_feature_matrix=np.array(sltp_feature_matrix,dtype=np.double)
distance_matrix_euclidean=np.zeros(shape=(sltp_feature_matrix.shape[0]),dtype=np.double)
for i in range(sltp_feature_matrix.shape[0]):
    distance_matrix_euclidean[i]=math.sqrt(sum(np.square(query_sltp_feature-sltp_feature_matrix[i])))

best=8
bestimgs=np.argsort(distance_matrix_euclidean)[:best]
classes=np.floor(bestimgs/10).astype(np.intc)+1
imgs=bestimgs%10

retrieve_images=[]
for i in range(best):
    image=io.imread("orl_faces\\s"+str(classes[i]).zfill(2)+"\\"+str(imgs[i])+".pgm")
    retrieve_images.append(image)
    
print("User Given Image:-")

fig = plt.figure(figsize=(8,8))
gs=GridSpec(int(math.floor(best/4))+1,4)

ax1=fig.add_subplot(gs[0,:])
ax1.imshow(queryimage,cmap='gray')
ax1.set_yticklabels([])
ax1.set_xticklabels([])

for i in range(best):
    ax=fig.add_subplot(gs[math.floor(i/4)+1,i%4])
    ax.imshow(retrieve_images[i],cmap='gray')
    ax.set_yticklabels([])
    ax.set_xticklabels([])

fig.show()
# Out:
# User Given Image:-
# C:\Users\Supreet\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
queryclass=math.floor(query/10)
queryimg=query%10
queryimage=io.imread("orl_faces\\s"+str(queryclass+1).zfill(2)+"\\"+str(queryimg)+".pgm")

query_sltp_feature=SLTP_feature_vector(queryimage)

sltp_feature_matrix=np.array(sltp_feature_matrix,dtype=np.double)
distance_matrix_d1=np.zeros(shape=(sltp_feature_matrix.shape[0]),dtype=np.double)
for i in range(sltp_feature_matrix.shape[0]):
    distance_matrix_d1[i]=sum(abs((query_sltp_feature-sltp_feature_matrix[i])/(1+query_sltp_feature+sltp_feature_matrix[i])))

best=8
bestimgs=np.argsort(distance_matrix_euclidean)[:best]
classes=np.floor(bestimgs/10).astype(np.intc)+1
imgs=bestimgs%10

retrieve_images=[]
for i in range(best):
    image=io.imread("orl_faces\\s"+str(classes[i]).zfill(2)+"\\"+str(imgs[i])+".pgm")
    retrieve_images.append(image)
    
print("User Given Image:-")

fig = plt.figure(figsize=(8,8))
gs=GridSpec(int(math.floor(best/4))+1,4)

ax1=fig.add_subplot(gs[0,:])
ax1.imshow(queryimage,cmap='gray')
ax1.set_yticklabels([])
ax1.set_xticklabels([])

for i in range(best):
    ax=fig.add_subplot(gs[math.floor(i/4)+1,i%4])
    ax.imshow(retrieve_images[i],cmap='gray')
    ax.set_yticklabels([])
    ax.set_xticklabels([])

fig.show()
# Out:
# User Given Image:-
# C:\Users\Supreet\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
